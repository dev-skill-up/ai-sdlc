# %% [markdown]
# ```{=latex}
# \usepackage{hyperref}
# \usepackage{graphicx}
# \usepackage{listings}
# \usepackage{textcomp}
# \usepackage{fancyvrb}
#
# \newcommand{\passthrough}[1]{\lstset{mathescape=false}#1\lstset{mathescape=true}}
# \newcommand{\tightlist}{}
# ```

# %% [markdown]
# ```{=latex}
# \title{Talk title}
# \author{Moshe Zadka -- https://cobordism.com}
# \date{}
#
# \begin{document}
# \begin{titlepage}
# \maketitle
# \end{titlepage}
#
# \frame{\titlepage}
# ```

# %% [markdown]
# In order to convert this to PDF, use `ides`:
#
# ```bash
# pip install ides
# python -m ides
# ```

# %% [markdown]
# ```{=latex}
# \begin{frame}
# \frametitle{Acknowledgement of Country}
#
# Hayward (in San Francisco Bay Area)
#
# Ancestral homeland of the Ohlone people
#
# \end{frame}
# ```

# %% [markdown]
# I live in Hayward,
# in the San Francisco Bay Area.
# I wish to acknowledge it as the
# ancestral homeland
# of the
# Ohlone people.

# %% [markdown]
# ```{=latex}
# \begin{frame}[fragile]
# \frametitle{Slide Title}
#
# Part of idea \pause
#
# Another part of idea
#
# \end{frame}
# ```

# %% [markdown]
# This is where the speaker notes go. They need to be comprehensive. The slide itself should be pretty thin.
# 2-3 sentences, often with `\pause` between them so that they are separated into different slides by
# Beamer.

# %% [markdown]
# ```{=latex}
# \begin{frame}[fragile]
# \frametitle{Slide with Python}
# ```

# %%
"This should be valid Python code"
# Out:
# 'This should be valid Python code'

# %% [markdown]
# ```{=latex}
# \end{frame}
# ```

# %% [markdown]
# Python code can go in code blocks.

# %% [markdown]
# ```{=latex}
# \end{document}
# ```
